# %%
import pandas as pd

# %% [markdown]
# Reading the csv files

# %%
file1_df = pd.read_csv("file1.csv")
file2_df = pd.read_csv("file2.csv")
file3_df = pd.read_csv("file3.csv")

# %%
display(file1_df)
display(file2_df.head())
file3_df.head()
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# Printing file's rows and columns

# %%
print("File 1's rows {0} and columns {1}".format(file1_df.shape[0], file1_df.shape[1]))
print("File 2's rows {0} and columns {1}".format(file2_df.shape[0], file2_df.shape[1]))
print("File 2's rows {0} and columns {1}".format(file3_df.shape[0], file3_df.shape[1]))
# Out:
# File 1's rows 4008 and columns 11
# File 2's rows 996 and columns 11
# File 2's rows 7070 and columns 11

# %% [markdown]
# Standardizing headers (lower case)

# %%
file1_df.columns = [column.lower() for column in file1_df.columns]
file1_df.head()
# Out:
#   customer          st gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly premium auto number of open complaints     policy type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle class  total claim amount
# ...

# %%
file2_df.columns = [column.lower() for column in file2_df.columns]
file2_df.head()
# Out:
#   customer          st gender education customer lifetime value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly premium auto number of open complaints  total claim amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       policy type  vehicle class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
file3_df.columns = [column.lower() for column in file3_df.columns]
file3_df.head()
# Out:
#   customer       state  customer lifetime value             education gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    income  monthly premium auto  number of open complaints    policy type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    total claim amount  vehicle class
# ...

# %% [markdown]
# Rearranging columns

# %%
file1_df = file1_df.rename(columns = { "st" : "state"})
file2_df = file2_df.rename(columns = { "st" : "state"})

file2_df = file2_df[['customer', 'state', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount']]

file3_df = file3_df[['customer', 'state', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount']]

# %% [markdown]
# Correct the values in the column 'customer lifetime value'. They are given as a percent, so divide them by 100 and change dtype to numerical type. (only 2 of the files need this step.)

# %%
file1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4008 entries, 0 to 4007
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   1071 non-null   object
#  1   state                      1071 non-null   object
#  2   gender                     954 non-null    object
#  3   education                  1071 non-null   object
#  4   customer lifetime value    1068 non-null   object
#  5   income                     1071 non-null   float64
#  6   monthly premium auto       1071 non-null   float64
#  7   number of open complaints  1071 non-null   object
#  8   policy type                1071 non-null   object
#  9   vehicle class              1071 non-null   object
#  10  total claim amount         1071 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 344.6+ KB

# %%
file2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   996 non-null    object
#  1   state                      996 non-null    object
#  2   gender                     991 non-null    object
#  3   education                  996 non-null    object
#  4   customer lifetime value    992 non-null    object
#  5   income                     996 non-null    int64
#  6   monthly premium auto       996 non-null    int64
#  7   number of open complaints  996 non-null    object
#  8   policy type                996 non-null    object
#  9   vehicle class              996 non-null    object
#  10  total claim amount         996 non-null    float64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 85.7+ KB

# %%
file3_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7070 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   7070 non-null   object
#  1   state                      7070 non-null   object
#  2   gender                     7070 non-null   object
#  3   education                  7070 non-null   object
#  4   customer lifetime value    7070 non-null   float64
#  5   income                     7070 non-null   int64
#  6   monthly premium auto       7070 non-null   int64
#  7   number of open complaints  7070 non-null   int64
#  8   policy type                7070 non-null   object
#  9   vehicle class              7070 non-null   object
#  10  total claim amount         7070 non-null   float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 607.7+ KB

# %%
file1_df["customer lifetime value"] = file1_df["customer lifetime value"].str.rstrip("%").astype("float")/100
file1_df.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer lifetime value      float64
# income                       float64
# monthly premium auto         float64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# dtype: object

# %%
file2_df["customer lifetime value"] = file2_df["customer lifetime value"].str.rstrip("%").astype("float")/100
file2_df.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer lifetime value      float64
# income                         int64
# monthly premium auto           int64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# dtype: object

# %%
file1_df.head()
# Out:
#   customer       state gender             education  customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                      NaN
# 1  QZ44356     Arizona      F              Bachelor                6979.5359
# 2  AI49188      Nevada      F              Bachelor               12887.4317
# 3  WW63253  California      M              Bachelor                7645.8618
# 4  GA49547  Washington      M  High School or Below                5363.0765
#
#     income  monthly premium auto number of open complaints     policy type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle class  total claim amount
# ...

# %% [markdown]
# Concatenate the three dataframes

# %%
data = pd.concat([file1_df, file2_df, file3_df], axis = 0)
data
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                 6979.535900      0.0                  94.0
# 2                12887.431700  48767.0                 108.0
# ...

# %% [markdown]
# Which columns are numerical?

# %%
data._get_numeric_data()
# Out:
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                 6979.535900      0.0                  94.0
# 2                12887.431700  48767.0                 108.0
# 3                 7645.861800      0.0                 106.0
# 4                 5363.076500  36357.0                  68.0
# ...                       ...      ...                   ...
# 7065             23405.987980  71941.0                  73.0
# 7066              3096.511217  21604.0                  79.0
# 7067              8163.890428      0.0                  85.0
# 7068              7524.442436  21941.0                  96.0
# 7069              2611.836866      0.0                  77.0
#
#       total claim amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 7065          198.234764
# ...

# %% [markdown]
# Which columns are categorical?

# %%
data.select_dtypes("object")
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      number of open complaints     policy type  vehicle class
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# ...

# %% [markdown]
# Perform the data cleaning operations mentioned so far in class
#
# Delete the column education and the number of open complaints from the dataframe.
# Check for duplicate rows in the data and remove if any.
# Filter out the data for customers who have an income of 0 or less. (Only show customers who HAVE an income.)

# %%
data = data.drop(["education", "number of open complaints"], axis= 1)
data
# Out:
#      customer       state gender  customer lifetime value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F              6979.535900      0.0
# 2     AI49188      Nevada      F             12887.431700  48767.0
# 3     WW63253  California      M              7645.861800      0.0
# 4     GA49547  Washington      M              5363.076500  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M             23405.987980  71941.0
# 7066  PK87824  California      F              3096.511217  21604.0
# 7067  TD14365  California      M              8163.890428      0.0
# 7068  UP19263  California      M              7524.442436  21941.0
# 7069  Y167826  California      M              2611.836866      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
data = data.drop_duplicates()
data
# Out:
#      customer       state gender  customer lifetime value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F              6979.535900      0.0
# 2     AI49188      Nevada      F             12887.431700  48767.0
# 3     WW63253  California      M              7645.861800      0.0
# 4     GA49547  Washington      M              5363.076500  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M             23405.987980  71941.0
# 7066  PK87824  California      F              3096.511217  21604.0
# 7067  TD14365  California      M              8163.890428      0.0
# 7068  UP19263  California      M              7524.442436  21941.0
# 7069  Y167826  California      M              2611.836866      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
data[data["income"] > 0]
# Out:
#      customer       state gender  customer lifetime value   income  \
# 2     AI49188      Nevada      F             12887.431700  48767.0
# 4     GA49547  Washington      M              5363.076500  36357.0
# 5     OC83172      Oregon      F              8256.297800  62902.0
# 6     XZ87318      Oregon      F              5380.898600  55350.0
# 8     DY87989      Oregon      M             24127.504000  14072.0
# ...       ...         ...    ...                      ...      ...
# 7063  TF56202  California      M              5032.165498  66367.0
# 7064  YM19146  California      F              4100.398533  47761.0
# 7065  LA72316  California      M             23405.987980  71941.0
# 7066  PK87824  California      F              3096.511217  21604.0
# 7068  UP19263  California      M              7524.442436  21941.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 2                    108.0   Personal Auto   Two-Door Car          566.472247
# ...

# %%
data[(data["income"] > 0) & (data["state"] == "Oregon")]
# Out:
#      customer   state gender  customer lifetime value   income  \
# 5     OC83172  Oregon      F              8256.297800  62902.0
# 6     XZ87318  Oregon      F              5380.898600  55350.0
# 8     DY87989  Oregon      M             24127.504000  14072.0
# 9     BQ94931  Oregon      F              7388.178100  28812.0
# 15    BW63560  Oregon    NaN              7463.139400  24599.0
# ...       ...     ...    ...                      ...      ...
# 6400  YV85096  Oregon      F              5272.005079  98110.0
# 6406  LC47479  Oregon      M             28622.314430  35442.0
# 6408  VQ78876  Oregon      F              4660.399573  89834.0
# 6414  JD86991  Oregon      M              5097.318657  67233.0
# 6415  QM60216  Oregon      M              8906.991433  58718.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 5                     69.0   Personal Auto   Two-Door Car          159.383042
# ...

# %%
data["state"].value_counts()
# Out:
# California    3030
# Oregon        2601
# Arizona       1629
# Nevada         882
# Washington     768
# Cali           120
# AZ              74
# WA              30
# Name: state, dtype: int64

# %%
data["gender"] = data["gender"].fillna("F")
display(data["gender"].value_counts(dropna = False))
# Out:
# /var/folders/yl/blp7v0ys1lzdfkls51wcv3l40000gn/T/ipykernel_16172/2781622075.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["gender"] = data["gender"].fillna("F")
# F         4680
# M         4368
# Male        40
# female      30
# Femal       17
# Name: gender, dtype: int64

# %% [markdown]
# Cleaning gender data by assigning only F or M character to bring consistency.

# %%
def clean_gender_value(gender):
    
    if gender in ["M", "Male", "m"]:
        return "M"
    elif gender in ["F", "Female", "female", "f", "femal", "Femal"]:
        return "F"
    else:
        return "U"
    
    
data["gender"] = list(map(clean_gender_value, data["gender"]))
data["gender"].value_counts()
# Out:
# /var/folders/yl/blp7v0ys1lzdfkls51wcv3l40000gn/T/ipykernel_16172/2786388621.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["gender"] = list(map(clean_gender_value, data["gender"]))
# F    4727
# M    4408
# Name: gender, dtype: int64
